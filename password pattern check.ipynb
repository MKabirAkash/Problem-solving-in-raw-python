# %%
password=input("enter your password: ")
flag=0
check="PAS"
check1=password[0:3]
flag=0
count=0
size=len(password)
if(check1==check):
  if(len(password)>10):
    for i in (password):
      if((i >= 'a' and i <= 'z') or (i >= 'A' and i <= 'Z')or (i >= '0' and i <= '9')):
        count=count
      else:
        count=count+1
    if(count>0):
      for i in range (size-1):
        if password[i]==password[i+1]:
          flag=1
        else:
          flag=flag
    else:
      flag=1
  else:
    flag=1
else:
  flag=1
if(flag==0):
  print("password is valid")
else:
  print("PAssword is invalid")
# Out:
# enter your password: PAShgfrdsjku!
# password is valid
