# %%
def leftrecursion():
  print("Give your input in E->Ea|b format")
  input1=input()
  list1=input1.split("->")
  st1=list1[0]
  st2=list1[1]
  values=st2.split("|")
  
  alpha=[]
  beta=[]
  betast1=[]
  alphast1=[]
  for i in range (len(values)):
    word=values[i]
    first=word[0]
    if(first==st1):
      withoutst1=word[1::]
      alpha.append(withoutst1)
    else:
      beta.append(word)
  for i in (beta):
    w1=i +"'"+st1
    betast1.append(w1)
  for i in (alpha):
    w2=i+st1+"'"
    alphast1.append(w2)

  
  st4=st1+"->"
  st5=st1+"'->"
  for i in (betast1):
    st4=st4+i+"|"
  for i in (alphast1):
    st5=st5+i+"|"
  st6=st5+"ɛ"
  print(st4)
  print(st6)

def leftfactoring():
  print("Give your input in E->Ea|b format")
  input1=input()
  list1=input1.split("->")
  st1=list1[0]
  st2=list1[1]
  values=st2.split("|")
  firsts=[]
  for i in values:
    first=i[0]
    for j in (firsts):
      if (first==j):
        continue
      else:
        firsts.append(first)
  


leftrecursion();


print("Type LR for Left Recursion")
print("Type LF for Left factoring")
print("Type PRE for Prefix evaluation")
print("Type POST for Postfix factoring")
print("Type TAR for Three Address representation")
# Out:
# Give your input in E->Ea|b format
# E->abAb|bEa|Eab|EAb|ab
# ['abAb', 'bEa', 'Eab', 'EAb', 'ab']
# E
# ['ab', 'Ab']
# ['abAb', 'bEa', 'ab']
# ["abAb'E", "bEa'E", "ab'E"]
# ["abE'", "AbE'"]
# E->abAb'E|bEa'E|ab'E|
# E'->abE'|AbE'||ɛ
# Type LR for Left Recursion
# Type LF for Left factoring
# Type PRE for Prefix evaluation
# Type POST for Postfix factoring
# Type TAR for Three Address representation

# %%
def prefix():
  print("Give your input")
  input1=input()
  l=list(input1)
  if(l[0]=="1" or l[0]=="2" or l[0]=="3" or l[0]=="4" or l[0]=="5" or l[0]=="6" or l[0]=="7" or l[0]=="8" or l[0]=="9" or l[0]=="0"):
    print("not ok")
  else:
    print(len(l))
    for i in range(0,len(l)-3):
      if(l[i]== "+"):
        if(l[i+1]=="1" or l[i+1]=="2" or l[i+1]=="3" or l[i+1]=="4" or l[i+1]=="5" or l[i+1]=="6" or l[i+1]=="7" or l[i+1]=="8" or l[i+1]=="9" or l[i+1]=="0"):
          if(l[i+2]=="1" or l[i+2]=="2" or l[i+2]=="3" or l[i+2]=="4" or l[i+2]=="5" or l[i+2]=="6" or l[i+2]=="7" or l[i+2]=="8" or l[i+2]=="9" or l[i+2]=="0"):
            new=int(l[i+1])+int(l[i+2])
            l[i]=new
            del l[i+1]
            del l[i+2]
    print(l)        
prefix()
# Out:
# Give your input
# +23
# 3
# ['+', '2', '3']

# %%
ll=['+','+',97,6,5,4,6]
print(ll[0])
for i in range (0,len(ll)-2):
      if(ll[i]== "+"):
        if(type(ll[i+1])==int and type(ll[i+2])==int ):
          new=int(ll[i+1])+int(ll[i+2])
          ll[i]=new
          del ll[i+1]
          del ll[i+2]
          print(i)
        else:
          continue  
      else:
        continue
print(ll)
# Out:
# +
# 1
# ['+', 103, 6, 4, 6]
