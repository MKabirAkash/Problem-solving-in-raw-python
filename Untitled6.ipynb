# %%
input1=input("enter your string")
length=len(input1)
flag1=0
flag2=0
flag3=0
if(length==20):
 if(input1[0]=='A' or input1[0]=='B'):
   for i in range (1,4):
     if(input1[i]>='A' or input1[i]<='Z'):
       flag1=flag1
     else:
        flag1=1
   if(flag1==0):
       for i in range(4,7):
         if(input1[i]>= '0' and input1[i]<='9'):
           flag2=flag2;
         else:
            flag2=1
   else:
       break
   if(flag2==0):
     for i in range(7,10):
       if (input1[i]>='a' and input1[i]<='z' ):
         flag3=flag3
       else:
          flag3=1
  else:
    break
  if(flag3==0):
    for i in range()

# %%
for i in range(1,4):
  print(i)
# Out:
# 1
# 2
# 3
