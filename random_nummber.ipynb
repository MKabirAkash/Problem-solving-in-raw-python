# %%
Z1 = [151234]
U1 = []
x=0
while (x<80):
    z = Z1[-1]
    z_sq = z**2
    suffix = z_sq % 1000000000
    prefix = int(suffix/1000)
    u = prefix/1000000
    U1.append(u)
    Z1.append(prefix)
    x=x+1



Z2= [11,8,17]
U2 = []



m=80


while True:
   
    z3 = Z2[-1]
    z2=Z2[-2]
    z1=Z2[-3]
    z_new =( 3*z3 + z2 + 7 * z1 ) % m

    if z_new in Z2:
      break
    else:
      Z2.append(z_new)
      u = z_new/m
      U2.append(u)

rand=[]

for i in range(0,64):
  rand.append(U1[i])
  x=x+1
j=64
for i in range(0,16):
  index=int(U2[i]*64)
  rand[index]=U1[j]
  j=j+1
print("Size of random number assigned vector :",len(rand))
print("random numbers vector:")
print(rand)
# Out:
# Size of random number assigned vector : 64
# random numbers vector:
# [0.289533, 0.899245, 0.64157, 0.612064, 0.710734, 0.307075, 0.295055, 0.057453, 0.300847, 0.508917, 0.996512, 0.036166, 0.307979, 0.851064, 0.829358, 0.057844, 0.519677, 0.666181, 0.797124, 0.406671, 0.300572, 0.119585, 0.396981, 0.418278, 0.142818, 0.863555, 0.727238, 0.875108, 0.814011, 0.613908, 0.064184, 0.745513, 0.789633, 0.520274, 0.685035, 0.272951, 0.502248, 0.834692, 0.010799, 0.283072, 0.343527, 0.836879, 0.36646, 0.292931, 0.375885, 0.116618, 0.922277, 0.594864, 0.863178, 0.076259, 0.815435, 0.934239, 0.802509, 0.020695, 0.428283, 0.426328, 0.755563, 0.875446, 0.405698, 0.590867, 0.733839, 0.593914, 0.34828, 0.298958]
