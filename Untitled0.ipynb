# %%
password=input("enter your password: ")
flag=0
check="PAS"
check1=password[0:3]
flag=0
count=0
size=len(password)
if(check1==check):
  if(len(password)>10):
    for i in (password):
      if((i >= 'a' and i <= 'z') or (i >= 'A' and i <= 'Z')or (i >= '0' and i <= '9')):
        count=count
      else:
        count=count+1
    if(count>0):
      for i in range (size-1):
        if password[i]==password[i+1]:
          flag=1
        else:
          flag=flag
    else:
      flag=1
  else:
    flag=1
else:
  flag=1
if(flag==0):
  print("password is valid")
else:
  print("PAssword is invalid")
# Out:
# enter your password: akash1234!
# PAssword is invalid

# %%
value=input("Enter your mail: ")
reverse_email=value[::-1]
uiu=".uiu.ac.bd"
compare=uiu[::-1]
flag1=0
for i in range(len(compare)-1) :
  if reverse_email[i]==compare[i]:
    flag1=flag1
  else:
    flag1=1
if(flag1==0):
  print("valid mail")
else:
  print("invalid mail")
# Out:
# Enter your mail: mkabirakash@gmail.com
# invalid mail

# %%
string1=input("Enter a string: ")
flag2=0
j=6
length=len(string1)
namecheck=string1[0:6]
if (namecheck=="MAHMUD"):

  string2=string1[j:length]
  string2_len=len(string2)
  if(string2_len==8):
    if(string1[j]=='3'):
      if(string2[1]>='0' and string2[1]<='9' ) and (string2[2]>='0' and string2[2]<='9' ):
        string3=string2[3:6:]
        if(string3=="COM" or string3=="UIU" or string3=="CSE"):
          if(string2[6]=='+' or string2[6]=='-'):
            if(string2[7]>='a' and string2[7]<='z'):
               flag2=flag2
            else:
              flag2=1
          else:
            flag2=1
        else:
          flag2=1
      else:
        flag2=1
    elif(string1[j]=='4'):
      if(string2[1]=='0' and string2[2]=='0' ):
        string3=string2[3:6:]
        if(string3=="COM" or string3=="UIU" or string3=="CSE"):
          if(string2[6]=='+' or string2[6]=='-'):
            if(string2[7]>='a' and string2[7]<='z'):
               flag2=flag2
            else:
              flag2=1
          else:
            flag2=1
        else:
          flag2=1
      else:
        flag2=1
    else:
      flag2=1
  elif(string2_len==7):
    if(string1[j]=='3'):
      if(string2[1]>='0' and string2[1]<='9' ) and (string2[2]>='0' and string2[2]<='9' ):
        string3=string2[3:6:]
        if(string3=="COM" or string3=="UIU" or string3=="CSE"):
          if(string2[6]>='a' and string2[6]<='z'):
            flag2=flag2
          else:
            flag2=1
        else:
          flag2=1
      else:
        flag2=1
    elif(string1[j]=='4'):
      if(string2[1]=='0' and string2[2]=='0' ):
        string3=string2[3:6:]
        if(string3=="COM" or string3=="UIU" or string3=="CSE"):
          if(string2[6]>='a' and string2[6]<='z'):
            flag2=flag2
          else:
            flag2=1
        else:
          flag2=1
      else:
        flag2=1
    else:
      flag2=1
  else:
    flag2=1
  if(flag2==0):
    print("valid string")
  else:
    print("invalid string")

else:
  print("Invalid string")
# Out:
# Enter a string: MAHMUD400COMA
# invalid string

# %%
# Out:
# enter your string: @456aah1A234gmail.comm
# its completed

# %%
str=input("enter your string: ")
length=len(str)
if(length==21):
  if(str[0]=='@' or str[0]=='#'):

    str1=str[1:4]
    count=0
    for i in (str1):
      if(i>='0' and i<='9'):
        count=count
      else:
        count=count+1
    if(count==0):
      str1num=int(str1)
      if(str1num % 2==0):
        str2=str[4:7]
        count2=0
        for i in (str2):
          if(i>='a' and i<='z'):
            count=count
          else:
            count=count+1
        if(count==0):
          if str[7]=='0' or str[7]=='1':
            if str[8]>='A' and str[8]<='Z':
              if(str[9]=='2' and str[10]=='3' and str[11]=='4'):
                str3=str[12:21]
                if(str3=="gmail.com"):
                  print("its Valid......")
                else:
                  print("invalid.ending doesn't match")
              else:
                print("invalid.id last digit doesn't match")
            else:
              print("invalid.no capital letter.")
          else:
            print("invalid.no binary value") 
        else:
          print("invalid.no consecutive small letter.")

      else:
        print("invalid.not even  decimal.")
    else:
      print("invalid.not  decimal.")
  else:
    print("invalid.starting doesn't match")
    
else:
  print("Invalid")
# Out:
# enter your string: @456aaa1A234gmail.com
# its Valid......

# %%
id=input("Enter your id :")
numbers=len(id)
if(numbers==9):
  id1=id[0:3]
  if(id1=="011" or id1=="111" or id1=="021"):
    id2=id[3:5]
    id2num=int(id2)
    if(id2num>=5 and id2num<=22):
      if(id[5]=='1' or id[5]=='2' or id[5]=='3'):
        id4=id[6:9]
        count=0
        for i in (id4):
          if(i>='0' and i<='9'):
            count=count
          else:
            count=count+1
        if(count==0):
          print("Valid UIU id")
        else:
          print("Invalid id number")

      else:
        print("trimester code doesn't match")
    else:
      print("year code doesn't match")


  else:
    print("Department code doesn't match")
else:
  print("id length doesn't match")
# Out:
# Enter your id :011155234
# trimester code doesn't match
