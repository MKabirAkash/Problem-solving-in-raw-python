# %%
input1=input("enter your input")
list1=input1.split(",")
answer=[]
keycount=0
spacecount=0
operandcount=0
punccount=0
unknown=0
for i in (list1):
  new=i.split[" "]
  if (new[0]=="int" or new[0]=="float" or new[0]=="for"):
    answer.append(keycount)
    answer.append("KEY")
    keycount=keycount+1
  else:
    continue
  if(len(new)>1):
    answer.append(sapcecount)
    answer.append("SPA")
    spacecount=spacecount+1
  else:
    continue
  for j in (new[1]):
    if (j=="+" or j== "-" or j=="*" or j =="/"):
      answer.append(operandcount)
      answer.append("OPE")
      operandcount=operandcount+1
    elif(j=="," or j=="." or j==">"):
      answer.append(punccount)
      answer.append("PUN")
      punccount=punccount+1
    else:
      answer.append(unknown)
      answer.append("UNK")
      unknown=unknown+1

print(answer)
