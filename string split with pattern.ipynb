# %%
value=input("Enter a string:")
print(value)
count=0
words=value.split(" ")
print(words)
for i in (words):
  count=count+1;
value2=input("Enter a number:")
value2=int(value2)
print("given input is:")
print(value2)
print("number of words: ")
print(count)
if(value2==count):
  wordlengths=[]
  for i in (words):
    count2=0
    for j in i:
      count2=count2+1
    wordlengths.append(count2)
  maxlength=wordlengths[0]
  for i in (wordlengths):
    if (i>maxlength):
      maxlength=i
  print(wordlengths)
  print(maxlength)
  str2="*"
  for i in range (maxlength+1):
    str2=str2+"*"
  print(str2)

  for i in (words):
    length=0
    for j in i:
      length=length+1;
    stars=maxlength-length+1
    str1=i
    for j in range (stars):
      str1=str1+"*"
    print("*"+str1)
  
  print(str2)

else:
  print("word count Doesn't match")
# Out:
# Enter a string:my name is akash
# my name is akash
# ['my', 'name', 'is', 'akash']
# Enter a number:4
# given input is:
# 4
# number of words:
# 4
# [2, 4, 2, 5]
# 5
# *******
# *my****
# *name**
# *is****
# *akash*
# *******
