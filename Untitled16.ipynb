# %%
a=27%7 +3
x=[a]
b=[]
print(a)
print(x[-1])
m=15
for i in range(0,11):
  x0=x[-1]
  xnew=(x0**2)%m
  if(xnew%2==0):
    b.append(0)
  else:
    b.append(1)
for i in range(0,11):
  print("b",i," is",b[i])
# Out:
# 9
# 9
# b 0  is 0
# b 1  is 0
# b 2  is 0
# b 3  is 0
# b 4  is 0
# b 5  is 0
# b 6  is 0
# b 7  is 0
# b 8  is 0
# b 9  is 0
# b 10  is 0

# %%
z=[12]

for i in range(0,3):
  x=z[-1]
  xnew=(13*x+11)%16
  print(xnew)
  mod=xnew%16
  z.append(mod)
print(z)
z1=[3,5]

for i in range(0,2):
  xi1=z1[-1]
  xi2=z1[-2]
  xnew1=(12* xi1**3 + 13* xi2**2 +2)
  print(xnew1)
  mod=xnew1%17
  z1.append(mod)
print(z1)
final=[]
u=[]
for i in range(0,4):
  znew=(z[i]+z1[i]**2)% 16
  final.append(znew)
  u.append(znew/16)
print(final)
print(u)
# Out:
# 7
# 6
# 9
# [12, 7, 6, 9]
# 1619
# 1095
# [3, 5, 4, 7]
# [5, 0, 6, 10]
# [0.3125, 0.0, 0.375, 0.625]
